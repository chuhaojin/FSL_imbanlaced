# %%
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7470045594
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4256808934525204080
# physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1"
# [None]

# %%
import numpy as np
print(np.random.randint(1, 6, size=10))

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']


n_epochs = 100
n_episodes = 100
n_way = 20
n_shot = 5
n_query = 15
n_examples = 350
im_width, im_height, channels = 84, 84, 3
h_dim = 64
z_dim = 64

# Load Train Dataset
train_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-train_600.npy')
train_dataset = train_dataset[:,:n_examples]
n_classes = train_dataset.shape[0]
print(train_dataset.shape)

test_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-test_600.npy')
n_test_classes = test_dataset.shape[0]
print(test_dataset.shape)
n_test_episodes = 600
n_test_examples = 600
n_test_way = 5
n_test_shot = 5
n_test_query = 15

def conv_block(inputs, out_channels, name='conv'):
    with tf.variable_scope(name):
        conv = tf.layers.conv2d(inputs, out_channels, kernel_size=3, padding='SAME')
        conv = tf.contrib.layers.batch_norm(conv, updates_collections=None, decay=0.99, scale=True, center=True)
        conv = tf.nn.relu(conv)
        conv = tf.contrib.layers.max_pool2d(conv, 2)
        return conv


def encoder(x, h_dim, z_dim, reuse=False):
    with tf.variable_scope('encoder', reuse=reuse):
        net = conv_block(x, h_dim, name='conv_1')
        net = conv_block(net, h_dim, name='conv_2')
        net = conv_block(net, h_dim, name='conv_3')
        net = conv_block(net, z_dim, name='conv_4')
        net = tf.contrib.layers.flatten(net)
        return net


def euclidean_distance(a, b):
    # a.shape = N x D
    # b.shape = M x D
    N, D = tf.shape(a)[0], tf.shape(a)[1]
    M = tf.shape(b)[0]
    a = tf.tile(tf.expand_dims(a, axis=1), (1, M, 1))
    b = tf.tile(tf.expand_dims(b, axis=0), (N, 1, 1))
    return tf.reduce_mean(tf.square(a - b), axis=2)
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7470045594
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9520837369469084433
# physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1"
#
# (64, 350, 84, 84, 3)
# (20, 600, 84, 84, 3)

# %%
def oversampling(batch_data, few_shot):
  balanced_data = np.zeros(batch_data.shape)
  balanced_data = np.copy(batch_data)
  temp_shot = len(batch_data[0])
  for i, n_few in enumerate(few_shot):
    choosed = np.random.randint(0, n_few, size=temp_shot - n_few)
    balanced_data[i, n_few:] = batch_data[i, choosed]
  return balanced_data


def require_unbalanced_data(train_dataset,
               n_classes=n_classes,
               n_way=n_way,
               n_shot=n_shot,
               n_query=n_query,
               n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  n_few_shot = np.random.randint(1, n_shot+1, size=n_way)
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
    selected = np.random.permutation(n_examples)[:n_few_shot[i] + n_query]
    support[i,:n_few_shot[i]] = train_dataset[epi_cls, selected[:n_few_shot[i]]]
    query[i] = train_dataset[epi_cls, selected[n_few_shot[i]:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels, n_few_shot


def uniform_sampling(train_dataset,
           n_classes=n_classes,
           n_way=n_way,
           n_shot=n_shot,
           n_query=n_query,
           n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
      selected = np.random.permutation(n_examples)[:n_shot + n_query]
      support[i] = train_dataset[epi_cls, selected[:n_shot]]
      query[i] = train_dataset[epi_cls, selected[n_shot:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels


def test_bench(sess,
        test_dataset,
        n_test_classes = n_test_classes,
        n_test_episodes=n_test_episodes, 
        n_test_way = n_test_way,
        n_test_shot = n_test_shot,
        n_test_query = n_test_query,
        n_test_examples=n_test_examples):
  print('Testing...')
  avg_acc = 0.
  n_test_classes = test_dataset.shape[0]
  for epi in range(n_test_episodes):
    # support, query, labels = uniform_sampling(test_dataset,
    #        n_classes=n_test_classes,
    #        n_way=n_test_way,
    #        n_shot=n_test_shot,
    #        n_query=n_test_query,
    #        n_examples=n_test_examples)
    support, query, labels, n_few_shot = require_unbalanced_data(test_dataset,
                                    n_classes=n_test_classes,
                                    n_way=n_test_way,
                                    n_shot=n_test_shot,
                                    n_query=n_test_query,
                                    n_examples=n_test_examples)
    support = oversampling(support, n_few_shot)
    ls, ac, = sess.run([ce_loss, acc], feed_dict={x: support, q: query, y:labels})
    avg_acc += ac
  avg_acc /= n_test_episodes
  print('Average Test Accuracy: {:.5f}'.format(avg_acc))
  return None

# %%
x = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
q = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
var_weight = tf.get_variable(name="variance_weight", shape=(1, 1))
var_b = tf.get_variable(name="variance_bias", shape=(1))
x_shape = tf.shape(x)
q_shape = tf.shape(q)
num_classes, num_support = x_shape[0], x_shape[1]
num_queries = q_shape[1]
y = tf.placeholder(tf.int64, [None, None])
y_one_hot = tf.one_hot(y, depth=num_classes)
emb_in = encoder(tf.reshape(x, [num_classes * num_support, im_height, im_width, channels]), h_dim, z_dim)
emb_dim = tf.shape(emb_in)[-1]
emb_x, q_variance = tf.nn.moments(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axes=1)
m_variance = tf.reshape(tf.reduce_mean(q_variance, axis=1), [num_classes, 1])
emb_variance = tf.nn.bias_add(tf.matmul(m_variance, var_weight), var_b)
emb_variance = tf.reshape(tf.nn.softmax(emb_variance, axis=0), [1, num_classes])

# emb_variance = tf.nn.softmax(emb_variance, axis=0)
emb_var = tf.tile(emb_variance, [num_queries * num_classes, 1])
# emb_x = tf.reduce_mean(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axis=1)
emb_q = encoder(tf.reshape(q, [num_classes * num_queries, im_height, im_width, channels]),
                h_dim, z_dim, reuse=True)

# q_mean, q_variance = tf.nn.moments(emb_q, axes=1)
# emb_q = (emb_q - q_mean) / q_variance
dists = euclidean_distance(emb_q, emb_x)
#修正后的距离函数
amend_dists = tf.multiply(emb_var, dists) * tf.to_float(num_classes)
log_p_y = tf.reshape(tf.nn.log_softmax(-amend_dists), [num_classes, num_queries, -1])
ce_loss = -tf.reduce_mean(tf.reshape(tf.reduce_sum(tf.multiply(y_one_hot, log_p_y), axis=-1), [-1]))
acc = tf.reduce_mean(tf.to_float(tf.equal(tf.argmax(log_p_y, axis=-1), y)))

train_op = tf.train.AdamOptimizer().minimize(ce_loss)

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
init_op = tf.global_variables_initializer()
sess.run(init_op)
# Out:
# WARNING:tensorflow:From <ipython-input-2-68bce633fcc8>:51: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-4-cfa6e2c8a9d5>:27: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
n_epochs = 100
for ep in range(n_epochs):
    for epi in range(n_episodes):
        # support, query, labels = uniform_sampling(train_dataset)
        support, query, labels, n_few_shot = require_unbalanced_data(train_dataset)
        support = oversampling(support, n_few_shot)
        _, ls, ac = sess.run([train_op, ce_loss, acc], feed_dict={x: support, q: query, y:labels})
        if (epi+1) % 50 == 0:
            std_str = '[epoch {}/{}, episode {}/{}] => loss: {:.5f}, acc: {:.5f}'
            print(std_str.format(ep+1, n_epochs, epi+1, n_episodes, ls, ac))
        if (ep + 1) % 3 == 0 and epi == 0:
            # w, b, m_v, emb_v = sess.run([var_weight, var_b, m_variance, emb_variance], 
            #             feed_dict={x: support, q: query, y:labels})
            # print("w:", w, "b:", b)
            # print("mean_var:", m_v)
            # print("emb_v:", emb_v)
            test_bench(sess=sess,test_dataset=test_dataset)
print("Training is over.")
test_bench(sess=sess, test_dataset=test_dataset)
# Out:
# [epoch 1/100, episode 50/100] => loss: 2.89203, acc: 0.12333
# [epoch 1/100, episode 100/100] => loss: 2.86302, acc: 0.13667
# [epoch 2/100, episode 50/100] => loss: 2.80389, acc: 0.17333
# [epoch 2/100, episode 100/100] => loss: 2.74254, acc: 0.19333
# Testing...
# Average Test Accuracy: 0.34542
# [epoch 3/100, episode 50/100] => loss: 2.74832, acc: 0.19000
# [epoch 3/100, episode 100/100] => loss: 2.75714, acc: 0.21333
# [epoch 4/100, episode 50/100] => loss: 2.69350, acc: 0.19333
# [epoch 4/100, episode 100/100] => loss: 2.78600, acc: 0.19333
# [epoch 5/100, episode 50/100] => loss: 2.63991, acc: 0.22333
# [epoch 5/100, episode 100/100] => loss: 2.70063, acc: 0.21667
# Testing...
# Average Test Accuracy: 0.37804
# [epoch 6/100, episode 50/100] => loss: 2.78270, acc: 0.17333
# [epoch 6/100, episode 100/100] => loss: 2.60944, acc: 0.21000
# [epoch 7/100, episode 50/100] => loss: 2.69622, acc: 0.18333
# [epoch 7/100, episode 100/100] => loss: 2.72599, acc: 0.20667
# [epoch 8/100, episode 50/100] => loss: 2.50511, acc: 0.24667
# [epoch 8/100, episode 100/100] => loss: 2.78559, acc: 0.18333
# Testing...
# Average Test Accuracy: 0.38462
# [epoch 9/100, episode 50/100] => loss: 2.67251, acc: 0.21000
# [epoch 9/100, episode 100/100] => loss: 2.59440, acc: 0.21333
# [epoch 10/100, episode 50/100] => loss: 2.65977, acc: 0.19000
# [epoch 10/100, episode 100/100] => loss: 2.80002, acc: 0.16333
# [epoch 11/100, episode 50/100] => loss: 2.46469, acc: 0.21667
# [epoch 11/100, episode 100/100] => loss: 2.47214, acc: 0.27333
# Testing...
# Average Test Accuracy: 0.42418
# [epoch 12/100, episode 50/100] => loss: 2.44622, acc: 0.27000
# [epoch 12/100, episode 100/100] => loss: 2.48096, acc: 0.22667
# [epoch 13/100, episode 50/100] => loss: 2.53126, acc: 0.21667
# [epoch 13/100, episode 100/100] => loss: 2.32209, acc: 0.29333
# [epoch 14/100, episode 50/100] => loss: 2.45140, acc: 0.26333
# [epoch 14/100, episode 100/100] => loss: 2.28615, acc: 0.30000
# Testing...
# Average Test Accuracy: 0.46698
# [epoch 15/100, episode 50/100] => loss: 2.27997, acc: 0.29333
# [epoch 15/100, episode 100/100] => loss: 2.25774, acc: 0.30333
# [epoch 16/100, episode 50/100] => loss: 2.09394, acc: 0.38000
# [epoch 16/100, episode 100/100] => loss: 2.38262, acc: 0.26000
# [epoch 17/100, episode 50/100] => loss: 2.33190, acc: 0.29000
# [epoch 17/100, episode 100/100] => loss: 2.32704, acc: 0.30333
# Testing...
# Average Test Accuracy: 0.49107
# [epoch 18/100, episode 50/100] => loss: 2.11430, acc: 0.33667
# [epoch 18/100, episode 100/100] => loss: 2.20014, acc: 0.32333
# [epoch 19/100, episode 50/100] => loss: 2.12352, acc: 0.35000
# [epoch 19/100, episode 100/100] => loss: 2.08270, acc: 0.36000
# [epoch 20/100, episode 50/100] => loss: 2.10028, acc: 0.31667
# [epoch 20/100, episode 100/100] => loss: 2.24606, acc: 0.32333
# Testing...
# Average Test Accuracy: 0.49511
# [epoch 21/100, episode 50/100] => loss: 2.15469, acc: 0.35333
# [epoch 21/100, episode 100/100] => loss: 2.13984, acc: 0.30333
# [epoch 22/100, episode 50/100] => loss: 2.14350, acc: 0.35667
# [epoch 22/100, episode 100/100] => loss: 1.78579, acc: 0.43667
# [epoch 23/100, episode 50/100] => loss: 2.33661, acc: 0.32000
# [epoch 23/100, episode 100/100] => loss: 2.14476, acc: 0.35333
# Testing...
# Average Test Accuracy: 0.50458
# [epoch 24/100, episode 50/100] => loss: 2.17850, acc: 0.33333
# [epoch 24/100, episode 100/100] => loss: 2.34509, acc: 0.25000
# [epoch 25/100, episode 50/100] => loss: 2.21967, acc: 0.32667
# [epoch 25/100, episode 100/100] => loss: 2.19871, acc: 0.32333
# [epoch 26/100, episode 50/100] => loss: 2.08206, acc: 0.40667
# [epoch 26/100, episode 100/100] => loss: 2.02026, acc: 0.37667
# Testing...
# Average Test Accuracy: 0.50904
# [epoch 27/100, episode 50/100] => loss: 1.99441, acc: 0.35333
# [epoch 27/100, episode 100/100] => loss: 2.16572, acc: 0.33333
# [epoch 28/100, episode 50/100] => loss: 1.97561, acc: 0.38333
# [epoch 28/100, episode 100/100] => loss: 1.95188, acc: 0.41667
# [epoch 29/100, episode 50/100] => loss: 2.17281, acc: 0.32333
# [epoch 29/100, episode 100/100] => loss: 1.93556, acc: 0.40333
# Testing...
# Average Test Accuracy: 0.51987
# [epoch 30/100, episode 50/100] => loss: 2.08769, acc: 0.33000
# [epoch 30/100, episode 100/100] => loss: 2.08575, acc: 0.35667
# [epoch 31/100, episode 50/100] => loss: 2.21895, acc: 0.30667
# [epoch 31/100, episode 100/100] => loss: 1.74818, acc: 0.44667
# [epoch 32/100, episode 50/100] => loss: 2.07700, acc: 0.33667
# [epoch 32/100, episode 100/100] => loss: 1.97842, acc: 0.40667
# Testing...
# Average Test Accuracy: 0.51609
# [epoch 33/100, episode 50/100] => loss: 1.76592, acc: 0.46000
# [epoch 33/100, episode 100/100] => loss: 1.96661, acc: 0.37333
# [epoch 34/100, episode 50/100] => loss: 2.17047, acc: 0.37333
# [epoch 34/100, episode 100/100] => loss: 2.16094, acc: 0.29333
# [epoch 35/100, episode 50/100] => loss: 1.93475, acc: 0.43333
# [epoch 35/100, episode 100/100] => loss: 2.08840, acc: 0.33333
# Testing...
# Average Test Accuracy: 0.53038
# [epoch 36/100, episode 50/100] => loss: 2.10312, acc: 0.34000
# [epoch 36/100, episode 100/100] => loss: 2.02532, acc: 0.37667
# [epoch 37/100, episode 50/100] => loss: 1.94714, acc: 0.40667
# [epoch 37/100, episode 100/100] => loss: 1.97381, acc: 0.39333
# [epoch 38/100, episode 50/100] => loss: 2.39123, acc: 0.26000
# [epoch 38/100, episode 100/100] => loss: 2.13833, acc: 0.34667
# Testing...
# Average Test Accuracy: 0.52442
# [epoch 39/100, episode 50/100] => loss: 1.98653, acc: 0.34333
# [epoch 39/100, episode 100/100] => loss: 1.59896, acc: 0.47333
# [epoch 40/100, episode 50/100] => loss: 2.02000, acc: 0.38667
# [epoch 40/100, episode 100/100] => loss: 1.80158, acc: 0.44000
# [epoch 41/100, episode 50/100] => loss: 1.93172, acc: 0.42333
# [epoch 41/100, episode 100/100] => loss: 2.19688, acc: 0.38333
# Testing...
# Average Test Accuracy: 0.53191
# [epoch 42/100, episode 50/100] => loss: 1.81554, acc: 0.44667
# [epoch 42/100, episode 100/100] => loss: 1.86635, acc: 0.40667
# [epoch 43/100, episode 50/100] => loss: 1.99402, acc: 0.39333
# [epoch 43/100, episode 100/100] => loss: 1.95839, acc: 0.39000
# [epoch 44/100, episode 50/100] => loss: 1.81278, acc: 0.41000
# [epoch 44/100, episode 100/100] => loss: 1.86915, acc: 0.44000
# Testing...
# Average Test Accuracy: 0.53720
# [epoch 45/100, episode 50/100] => loss: 1.93670, acc: 0.41667
# [epoch 45/100, episode 100/100] => loss: 1.91811, acc: 0.39667
# [epoch 46/100, episode 50/100] => loss: 2.24795, acc: 0.31000
# [epoch 46/100, episode 100/100] => loss: 1.82617, acc: 0.38667
# [epoch 47/100, episode 50/100] => loss: 1.75347, acc: 0.44333
# [epoch 47/100, episode 100/100] => loss: 1.91122, acc: 0.42333
# Testing...
# Average Test Accuracy: 0.53851
# [epoch 48/100, episode 50/100] => loss: 1.64545, acc: 0.43333
# [epoch 48/100, episode 100/100] => loss: 2.02117, acc: 0.39333
# [epoch 49/100, episode 50/100] => loss: 1.83604, acc: 0.42333
# [epoch 49/100, episode 100/100] => loss: 1.97843, acc: 0.37000
# [epoch 50/100, episode 50/100] => loss: 1.96810, acc: 0.41667
# [epoch 50/100, episode 100/100] => loss: 2.22564, acc: 0.33000
# Testing...
# Average Test Accuracy: 0.53200
# [epoch 51/100, episode 50/100] => loss: 1.51505, acc: 0.50000
# [epoch 51/100, episode 100/100] => loss: 1.82738, acc: 0.41667
# [epoch 52/100, episode 50/100] => loss: 2.12603, acc: 0.36000
# [epoch 52/100, episode 100/100] => loss: 1.84715, acc: 0.45000
# [epoch 53/100, episode 50/100] => loss: 2.05344, acc: 0.37000
# [epoch 53/100, episode 100/100] => loss: 1.68487, acc: 0.43000
# Testing...
# Average Test Accuracy: 0.53229
# [epoch 54/100, episode 50/100] => loss: 2.01911, acc: 0.35000
# [epoch 54/100, episode 100/100] => loss: 1.97942, acc: 0.40333
# [epoch 55/100, episode 50/100] => loss: 1.85958, acc: 0.40667
# [epoch 55/100, episode 100/100] => loss: 1.62372, acc: 0.45333
# [epoch 56/100, episode 50/100] => loss: 2.26407, acc: 0.34333
# [epoch 56/100, episode 100/100] => loss: 1.83799, acc: 0.40667
# Testing...
# Average Test Accuracy: 0.52773
# [epoch 57/100, episode 50/100] => loss: 1.78621, acc: 0.45667
# [epoch 57/100, episode 100/100] => loss: 1.79012, acc: 0.38667
# [epoch 58/100, episode 50/100] => loss: 1.78100, acc: 0.43000
# [epoch 58/100, episode 100/100] => loss: 1.73901, acc: 0.43333
# [epoch 59/100, episode 50/100] => loss: 1.65094, acc: 0.47667
# [epoch 59/100, episode 100/100] => loss: 1.69846, acc: 0.48000
# Testing...
# Average Test Accuracy: 0.52549
# [epoch 60/100, episode 50/100] => loss: 1.76852, acc: 0.45667
# [epoch 60/100, episode 100/100] => loss: 1.87263, acc: 0.39000
# [epoch 61/100, episode 50/100] => loss: 1.72245, acc: 0.44000
# [epoch 61/100, episode 100/100] => loss: 2.01111, acc: 0.36333
# [epoch 62/100, episode 50/100] => loss: 1.91136, acc: 0.37667
# [epoch 62/100, episode 100/100] => loss: 1.48019, acc: 0.56667
# Testing...
# Average Test Accuracy: 0.53729
# [epoch 63/100, episode 50/100] => loss: 1.82194, acc: 0.42667
# [epoch 63/100, episode 100/100] => loss: 1.69761, acc: 0.48667
# [epoch 64/100, episode 50/100] => loss: 1.75657, acc: 0.45000
# [epoch 64/100, episode 100/100] => loss: 1.78031, acc: 0.45667
# [epoch 65/100, episode 50/100] => loss: 1.56826, acc: 0.49667
# [epoch 65/100, episode 100/100] => loss: 1.46937, acc: 0.49667
# Testing...
# Average Test Accuracy: 0.54344
# [epoch 66/100, episode 50/100] => loss: 1.79923, acc: 0.40333
# [epoch 66/100, episode 100/100] => loss: 1.78876, acc: 0.42000
# [epoch 67/100, episode 50/100] => loss: 1.71124, acc: 0.47333
# [epoch 67/100, episode 100/100] => loss: 1.87265, acc: 0.43000
# [epoch 68/100, episode 50/100] => loss: 1.68790, acc: 0.48000
# [epoch 68/100, episode 100/100] => loss: 1.68669, acc: 0.48000
# Testing...
# Average Test Accuracy: 0.53793
# [epoch 69/100, episode 50/100] => loss: 1.70464, acc: 0.44333
# [epoch 69/100, episode 100/100] => loss: 1.55932, acc: 0.52000
# [epoch 70/100, episode 50/100] => loss: 2.12933, acc: 0.35333
# [epoch 70/100, episode 100/100] => loss: 1.60424, acc: 0.51000
# [epoch 71/100, episode 50/100] => loss: 1.65627, acc: 0.42000
# [epoch 71/100, episode 100/100] => loss: 1.63345, acc: 0.46333
# Testing...
# Average Test Accuracy: 0.54147
# [epoch 72/100, episode 50/100] => loss: 1.49083, acc: 0.52333
# [epoch 72/100, episode 100/100] => loss: 1.53878, acc: 0.51000
# [epoch 73/100, episode 50/100] => loss: 1.77909, acc: 0.41000
# [epoch 73/100, episode 100/100] => loss: 2.12980, acc: 0.33667
# [epoch 74/100, episode 50/100] => loss: 1.73196, acc: 0.50667
# [epoch 74/100, episode 100/100] => loss: 1.92201, acc: 0.37333
# Testing...
# Average Test Accuracy: 0.53973
# [epoch 75/100, episode 50/100] => loss: 1.54260, acc: 0.51333
# [epoch 75/100, episode 100/100] => loss: 1.84487, acc: 0.39333
# [epoch 76/100, episode 50/100] => loss: 1.30731, acc: 0.53667
# [epoch 76/100, episode 100/100] => loss: 1.65029, acc: 0.45667
# [epoch 77/100, episode 50/100] => loss: 1.51858, acc: 0.53667
# [epoch 77/100, episode 100/100] => loss: 1.62874, acc: 0.46000
# Testing...
# Average Test Accuracy: 0.54376
# [epoch 78/100, episode 50/100] => loss: 1.91706, acc: 0.39333
# [epoch 78/100, episode 100/100] => loss: 1.59491, acc: 0.51667
# [epoch 79/100, episode 50/100] => loss: 1.59988, acc: 0.52667
# [epoch 79/100, episode 100/100] => loss: 1.56574, acc: 0.51667
# [epoch 80/100, episode 50/100] => loss: 1.83262, acc: 0.40667
# [epoch 80/100, episode 100/100] => loss: 1.78477, acc: 0.41333
# Testing...
# Average Test Accuracy: 0.55007
# [epoch 81/100, episode 50/100] => loss: 1.64473, acc: 0.47333
# [epoch 81/100, episode 100/100] => loss: 1.67240, acc: 0.49333
# [epoch 82/100, episode 50/100] => loss: 1.92423, acc: 0.41000
# [epoch 82/100, episode 100/100] => loss: 1.26419, acc: 0.60333
# [epoch 83/100, episode 50/100] => loss: 1.62233, acc: 0.44667
# [epoch 83/100, episode 100/100] => loss: 1.80105, acc: 0.42333
# Testing...
# Average Test Accuracy: 0.54038
# [epoch 84/100, episode 50/100] => loss: 1.53665, acc: 0.49333
# [epoch 84/100, episode 100/100] => loss: 1.65462, acc: 0.45667
# [epoch 85/100, episode 50/100] => loss: 1.67223, acc: 0.49000
# [epoch 85/100, episode 100/100] => loss: 1.76803, acc: 0.43333
# [epoch 86/100, episode 50/100] => loss: 1.67571, acc: 0.46333
# [epoch 86/100, episode 100/100] => loss: 1.78770, acc: 0.48000
# Testing...
# Average Test Accuracy: 0.54016
# [epoch 87/100, episode 50/100] => loss: 1.45639, acc: 0.49000
# [epoch 87/100, episode 100/100] => loss: 1.66392, acc: 0.42667
# [epoch 88/100, episode 50/100] => loss: 1.93046, acc: 0.40000
# [epoch 88/100, episode 100/100] => loss: 1.57324, acc: 0.47333
# [epoch 89/100, episode 50/100] => loss: 1.73082, acc: 0.42333
# [epoch 89/100, episode 100/100] => loss: 1.69981, acc: 0.45000
# Testing...
# Average Test Accuracy: 0.54287
# [epoch 90/100, episode 50/100] => loss: 1.65868, acc: 0.46333
# [epoch 90/100, episode 100/100] => loss: 1.60581, acc: 0.46667
# [epoch 91/100, episode 50/100] => loss: 1.83276, acc: 0.42000
# [epoch 91/100, episode 100/100] => loss: 1.67482, acc: 0.48333
# [epoch 92/100, episode 50/100] => loss: 1.61737, acc: 0.48667
# [epoch 92/100, episode 100/100] => loss: 1.57396, acc: 0.48333
# Testing...
# Average Test Accuracy: 0.53500
# [epoch 93/100, episode 50/100] => loss: 1.40097, acc: 0.57000
# [epoch 93/100, episode 100/100] => loss: 1.72444, acc: 0.46667
# [epoch 94/100, episode 50/100] => loss: 1.35034, acc: 0.52667
# [epoch 94/100, episode 100/100] => loss: 1.27795, acc: 0.61667
# [epoch 95/100, episode 50/100] => loss: 1.88365, acc: 0.38333
# [epoch 95/100, episode 100/100] => loss: 1.98670, acc: 0.35667
# Testing...
# Average Test Accuracy: 0.52176
# [epoch 96/100, episode 50/100] => loss: 2.07011, acc: 0.35333
# [epoch 96/100, episode 100/100] => loss: 1.44145, acc: 0.55000
# [epoch 97/100, episode 50/100] => loss: 1.69710, acc: 0.42333
# [epoch 97/100, episode 100/100] => loss: 1.73591, acc: 0.45000
# [epoch 98/100, episode 50/100] => loss: 1.74156, acc: 0.47000
# [epoch 98/100, episode 100/100] => loss: 1.83054, acc: 0.43333
# Testing...
# Average Test Accuracy: 0.53233
# [epoch 99/100, episode 50/100] => loss: 2.03431, acc: 0.36333
# [epoch 99/100, episode 100/100] => loss: 1.74271, acc: 0.42000
# [epoch 100/100, episode 50/100] => loss: 1.80726, acc: 0.39667
# [epoch 100/100, episode 100/100] => loss: 1.60606, acc: 0.45000
# Training is over.
# Testing...
# Average Test Accuracy: 0.53167

# %%
'''
import glob
import os
import numpy as np
import cv2

n_train_classes = 64
n_test_classes = 20
n_examples, width, height, channels = 600, 84, 84, 3

root_path = '/content/drive/My Drive/data/miniimagenet'
train_path = os.path.join(root_path, 'train')
test_path = os.path.join(root_path, 'test')

train_dirs = [f for f in glob.glob(os.path.join(train_path, '*')) if os.path.isdir(f)]
test_dirs = [f for f in glob.glob(os.path.join(test_path, '*')) if os.path.isdir(f)]
print(len(train_dirs))

assert len(train_dirs) == n_train_classes
assert len(test_dirs) == n_test_classes

read_and_resize = lambda x: cv2.imread(x, 1)

def sample_dataset(dataset, dirs, name='train'):
    for i, d in enumerate(dirs):
        fs = np.asarray(glob.glob(os.path.join(d, '*.jpg')))
        fs = fs[np.random.permutation(len(fs))][:n_examples]
        for j, f in enumerate(fs):
            dataset[i, j] = read_and_resize(f)
        print('{}: {} of {}'.format(name, i + 1, len(dirs)))
    return dataset

train_dataset = np.zeros((n_train_classes, n_examples, width, height, channels), dtype=np.uint8)
train_dataset = sample_dataset(train_dataset, train_dirs)
np.save('/content/drive/My Drive/data/mini-imagenet-train_600.npy', train_dataset)
del train_dataset

test_dataset = np.zeros((n_test_classes, n_examples, width, height, channels), dtype=np.uint8)
test_dataset = sample_dataset(test_dataset, test_dirs, name='test')
np.save('/content/drive/My Drive/data/mini-imagenet-test_600.npy', test_dataset)
'''

# %%
img = tf.Variable(tf.random_normal([3, 4]))
axis = list(range(len(img.get_shape()) - 1))
mean, variance = tf.nn.moments(img, axis)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    rs = sess.run(img)
    print(rs)
    print(rs.shape)
    print(axis)
    resultMean = sess.run(mean)
    print('resultMean',resultMean)
    resultVar = sess.run(variance)
    print('resultVar',resultVar)
# Out:
# [[-0.15628773 -0.04902783  1.0848862  -1.4387043 ]
#  [-1.7748989  -1.9277954   1.2477913  -0.14888158]
#  [-0.31883678 -0.5837216  -2.0567434   0.48701447]]
# (3, 4)
# [0]
# resultMean [-0.7500078  -0.8535149   0.09197799 -0.36685714]
# resultVar [0.5296046  0.62468886 2.312925   0.6418221 ]

# %%
#!unzip miniimagenet.zip > /dev/null
