# %%
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7470045594
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4256808934525204080
# physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1"
# [None]

# %%
import numpy as np
print(np.random.randint(1, 6, size=10))

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']


n_epochs = 100
n_episodes = 100
n_way = 20
n_shot = 5
n_query = 15
n_examples = 350
im_width, im_height, channels = 84, 84, 3
h_dim = 64
z_dim = 64

# Load Train Dataset
train_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-train_600.npy')
train_dataset = train_dataset[:,:n_examples]
n_classes = train_dataset.shape[0]
print(train_dataset.shape)

test_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-test_600.npy')
n_test_classes = test_dataset.shape[0]
print(test_dataset.shape)
n_test_episodes = 600
n_test_examples = 600
n_test_way = 20
n_test_shot = 5
n_test_query = 15

'''
epi_classes = np.random.permutation(n_classes)[:n_way]
support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
for i, epi_cls in enumerate(epi_classes):
    selected = np.random.permutation(n_examples)[:n_shot + n_query]
    support[i] = train_dataset[epi_cls, selected[:n_shot]]
    query[i] = train_dataset[epi_cls, selected[n_shot:]]
# support = np.expand_dims(support, axis=-1)
# query = np.expand_dims(query, axis=-1)
labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
'''


def conv_block(inputs, out_channels, name='conv'):
    with tf.variable_scope(name):
        conv = tf.layers.conv2d(inputs, out_channels, kernel_size=3, padding='SAME')
        conv = tf.contrib.layers.batch_norm(conv, updates_collections=None, decay=0.99, scale=True, center=True)
        conv = tf.nn.relu(conv)
        conv = tf.contrib.layers.max_pool2d(conv, 2)
        return conv


def encoder(x, h_dim, z_dim, reuse=False):
    with tf.variable_scope('encoder', reuse=reuse):
        net = conv_block(x, h_dim, name='conv_1')
        net = conv_block(net, h_dim, name='conv_2')
        net = conv_block(net, h_dim, name='conv_3')
        net = conv_block(net, z_dim, name='conv_4')
        net = tf.contrib.layers.flatten(net)
        return net


def euclidean_distance(a, b):
    # a.shape = N x D
    # b.shape = M x D
    N, D = tf.shape(a)[0], tf.shape(a)[1]
    M = tf.shape(b)[0]
    a = tf.tile(tf.expand_dims(a, axis=1), (1, M, 1))
    b = tf.tile(tf.expand_dims(b, axis=0), (N, 1, 1))
    return tf.reduce_mean(tf.square(a - b), axis=2)
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15956161332
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10650190914790153145
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#
# (64, 350, 84, 84, 3)
# (20, 600, 84, 84, 3)

# %%
def oversampling(batch_data, few_shot):
  balanced_data = np.zeros(batch_data.shape)
  balanced_data = np.copy(batch_data)
  temp_shot = len(batch_data[0])
  for i, n_few in enumerate(few_shot):
    choosed = np.random.randint(0, n_few, size=temp_shot - n_few)
    balanced_data[i, n_few:] = batch_data[i, choosed]
  return balanced_data


def require_unbalanced_data(train_dataset,
               n_classes=n_classes,
               n_way=n_way,
               n_shot=n_shot,
               n_query=n_query,
               n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  n_few_shot = np.random.randint(1, n_shot+1, size=n_way)
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
    selected = np.random.permutation(n_examples)[:n_few_shot[i] + n_query]
    support[i,:n_few_shot[i]] = train_dataset[epi_cls, selected[:n_few_shot[i]]]
    query[i] = train_dataset[epi_cls, selected[n_few_shot[i]:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels, n_few_shot


def uniform_sampling(train_dataset,
           n_classes=n_classes,
           n_way=n_way,
           n_shot=n_shot,
           n_query=n_query,
           n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
      selected = np.random.permutation(n_examples)[:n_shot + n_query]
      support[i] = train_dataset[epi_cls, selected[:n_shot]]
      query[i] = train_dataset[epi_cls, selected[n_shot:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels


def test_bench(sess,
        test_dataset,
        n_test_classes = n_test_classes,
        n_test_episodes=n_test_episodes, 
        n_test_way = n_test_way,
        n_test_shot = n_test_shot,
        n_test_query = n_test_query,
        n_test_examples=n_test_examples):
  print('Testing...')
  avg_acc = 0.
  n_test_classes = test_dataset.shape[0]
  for epi in range(n_test_episodes):
    # support, query, labels = uniform_sampling(test_dataset,
    #        n_classes=n_test_classes,
    #        n_way=n_test_way,
    #        n_shot=n_test_shot,
    #        n_query=n_test_query,
    #        n_examples=n_test_examples)
    support, query, labels, n_few_shot = require_unbalanced_data(test_dataset,
                                    n_classes=n_test_classes,
                                    n_way=n_test_way,
                                    n_shot=n_test_shot,
                                    n_query=n_test_query,
                                    n_examples=n_test_examples)
    support = oversampling(support, n_few_shot)
    ls, ac, = sess.run([ce_loss, acc], feed_dict={x: support, q: query, y:labels})
    avg_acc += ac
  avg_acc /= n_test_episodes
  print('Average Test Accuracy: {:.5f}'.format(avg_acc))
  return None

# %%
x = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
q = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
var_weight = tf.get_variable(name="variance_weight", shape=(1, 1))
var_b = tf.get_variable(name="variance_bias", shape=(1))
x_shape = tf.shape(x)
q_shape = tf.shape(q)
num_classes, num_support = x_shape[0], x_shape[1]
num_queries = q_shape[1]
y = tf.placeholder(tf.int64, [None, None])
y_one_hot = tf.one_hot(y, depth=num_classes)
emb_in = encoder(tf.reshape(x, [num_classes * num_support, im_height, im_width, channels]), h_dim, z_dim)
emb_dim = tf.shape(emb_in)[-1]
emb_x, q_variance = tf.nn.moments(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axes=1)
m_variance = tf.reshape(tf.reduce_mean(q_variance, axis=1), [num_classes, 1])
emb_variance = tf.nn.bias_add(tf.matmul(m_variance, var_weight), var_b)
emb_variance = tf.reshape(tf.nn.softmax(emb_variance, axis=0), [1, num_classes])

# emb_variance = tf.nn.softmax(emb_variance, axis=0)
emb_var = tf.tile(emb_variance, [num_queries * num_classes, 1])
# emb_x = tf.reduce_mean(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axis=1)
emb_q = encoder(tf.reshape(q, [num_classes * num_queries, im_height, im_width, channels]),
                h_dim, z_dim, reuse=True)

# q_mean, q_variance = tf.nn.moments(emb_q, axes=1)
# emb_q = (emb_q - q_mean) / q_variance
dists = euclidean_distance(emb_q, emb_x)
amend_dists = tf.multiply(emb_var, dists) * tf.to_float(num_classes)
log_p_y = tf.reshape(tf.nn.log_softmax(-amend_dists), [num_classes, num_queries, -1])
ce_loss = -tf.reduce_mean(tf.reshape(tf.reduce_sum(tf.multiply(y_one_hot, log_p_y), axis=-1), [-1]))
acc = tf.reduce_mean(tf.to_float(tf.equal(tf.argmax(log_p_y, axis=-1), y)))

train_op = tf.train.AdamOptimizer().minimize(ce_loss)

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
init_op = tf.global_variables_initializer()
sess.run(init_op)
# Out:
# WARNING:tensorflow:From <ipython-input-3-cb5a1d61a2f4>:51: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-5-cfa6e2c8a9d5>:27: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
n_epochs = 100
for ep in range(n_epochs):
    for epi in range(n_episodes):
        # support, query, labels = uniform_sampling(train_dataset)
        support, query, labels, n_few_shot = require_unbalanced_data(train_dataset)
        support = oversampling(support, n_few_shot)
        _, ls, ac = sess.run([train_op, ce_loss, acc], feed_dict={x: support, q: query, y:labels})
        if (epi+1) % 50 == 0:
            std_str = '[epoch {}/{}, episode {}/{}] => loss: {:.5f}, acc: {:.5f}'
            print(std_str.format(ep+1, n_epochs, epi+1, n_episodes, ls, ac))
        if (ep + 1) % 3 == 0 and epi == 0:
            # w, b, m_v, emb_v = sess.run([var_weight, var_b, m_variance, emb_variance], 
            #             feed_dict={x: support, q: query, y:labels})
            # print("w:", w, "b:", b)
            # print("mean_var:", m_v)
            # print("emb_v:", emb_v)
            test_bench(sess=sess,test_dataset=test_dataset)
print("Training is over.")
test_bench(sess=sess, test_dataset=test_dataset)
# Out:
# [epoch 1/100, episode 50/100] => loss: 2.90612, acc: 0.13667
# [epoch 1/100, episode 100/100] => loss: 2.79434, acc: 0.19000
# [epoch 2/100, episode 50/100] => loss: 2.81547, acc: 0.14667
# [epoch 2/100, episode 100/100] => loss: 2.60334, acc: 0.21000
# Testing...
# Average Test Accuracy: 0.15126
# [epoch 3/100, episode 50/100] => loss: 2.51266, acc: 0.24333
# [epoch 3/100, episode 100/100] => loss: 2.58142, acc: 0.20000
# [epoch 4/100, episode 50/100] => loss: 2.71062, acc: 0.20333
# [epoch 4/100, episode 100/100] => loss: 2.58526, acc: 0.24333
# [epoch 5/100, episode 50/100] => loss: 2.47598, acc: 0.25333
# [epoch 5/100, episode 100/100] => loss: 2.38723, acc: 0.27333
# Testing...
# Average Test Accuracy: 0.18276
# [epoch 6/100, episode 50/100] => loss: 2.65541, acc: 0.24333
# [epoch 6/100, episode 100/100] => loss: 2.52444, acc: 0.25667
# [epoch 7/100, episode 50/100] => loss: 2.41876, acc: 0.33333
# [epoch 7/100, episode 100/100] => loss: 2.25404, acc: 0.36333
# [epoch 8/100, episode 50/100] => loss: 2.57727, acc: 0.21667
# [epoch 8/100, episode 100/100] => loss: 2.36246, acc: 0.30000
# Testing...
# Average Test Accuracy: 0.20849
# [epoch 9/100, episode 50/100] => loss: 2.31824, acc: 0.25333
# [epoch 9/100, episode 100/100] => loss: 2.28945, acc: 0.28333
# [epoch 10/100, episode 50/100] => loss: 2.38254, acc: 0.26667
# [epoch 10/100, episode 100/100] => loss: 2.32537, acc: 0.30000
# [epoch 11/100, episode 50/100] => loss: 2.13054, acc: 0.32333
# [epoch 11/100, episode 100/100] => loss: 2.33251, acc: 0.33000
# Testing...
# Average Test Accuracy: 0.21897
# [epoch 12/100, episode 50/100] => loss: 2.34659, acc: 0.28333
# [epoch 12/100, episode 100/100] => loss: 2.24671, acc: 0.32667
# [epoch 13/100, episode 50/100] => loss: 2.31435, acc: 0.26333
# [epoch 13/100, episode 100/100] => loss: 2.28975, acc: 0.29667
# [epoch 14/100, episode 50/100] => loss: 2.17026, acc: 0.34333
# [epoch 14/100, episode 100/100] => loss: 2.20488, acc: 0.31000
# Testing...
# Average Test Accuracy: 0.22569
# [epoch 15/100, episode 50/100] => loss: 2.27332, acc: 0.33333
# [epoch 15/100, episode 100/100] => loss: 2.13531, acc: 0.35000
# [epoch 16/100, episode 50/100] => loss: 2.28331, acc: 0.27333
# [epoch 16/100, episode 100/100] => loss: 2.02121, acc: 0.37000
# [epoch 17/100, episode 50/100] => loss: 2.05442, acc: 0.35667
# [epoch 17/100, episode 100/100] => loss: 1.85610, acc: 0.43333
# Testing...
# Average Test Accuracy: 0.23234
# [epoch 18/100, episode 50/100] => loss: 2.14269, acc: 0.35333
# [epoch 18/100, episode 100/100] => loss: 2.53236, acc: 0.25667
# [epoch 19/100, episode 50/100] => loss: 2.22576, acc: 0.28333
# [epoch 19/100, episode 100/100] => loss: 2.18584, acc: 0.32333
# [epoch 20/100, episode 50/100] => loss: 2.17889, acc: 0.31333
# [epoch 20/100, episode 100/100] => loss: 1.98966, acc: 0.40333
# Testing...
# Average Test Accuracy: 0.23803
# [epoch 21/100, episode 50/100] => loss: 2.15417, acc: 0.35000
# [epoch 21/100, episode 100/100] => loss: 2.09830, acc: 0.33000
# [epoch 22/100, episode 50/100] => loss: 2.09770, acc: 0.33000
# [epoch 22/100, episode 100/100] => loss: 2.10486, acc: 0.37333
# [epoch 23/100, episode 50/100] => loss: 2.19665, acc: 0.30000
# [epoch 23/100, episode 100/100] => loss: 1.96516, acc: 0.37333
# Testing...
# Average Test Accuracy: 0.23834
# [epoch 24/100, episode 50/100] => loss: 1.92408, acc: 0.44000
# [epoch 24/100, episode 100/100] => loss: 2.05801, acc: 0.38000
# [epoch 25/100, episode 50/100] => loss: 1.69619, acc: 0.46667
# [epoch 25/100, episode 100/100] => loss: 2.28175, acc: 0.28333
# [epoch 26/100, episode 50/100] => loss: 1.95396, acc: 0.41667
# [epoch 26/100, episode 100/100] => loss: 1.72098, acc: 0.43667
# Testing...
# Average Test Accuracy: 0.25152
# [epoch 27/100, episode 50/100] => loss: 2.14836, acc: 0.32667
# [epoch 27/100, episode 100/100] => loss: 1.98937, acc: 0.35667
# [epoch 28/100, episode 50/100] => loss: 2.06840, acc: 0.36667
# [epoch 28/100, episode 100/100] => loss: 2.07417, acc: 0.35333
# [epoch 29/100, episode 50/100] => loss: 1.61322, acc: 0.51667
# [epoch 29/100, episode 100/100] => loss: 1.91828, acc: 0.37333
# Testing...
# Average Test Accuracy: 0.25554
# [epoch 30/100, episode 50/100] => loss: 1.82895, acc: 0.43000
# [epoch 30/100, episode 100/100] => loss: 2.09502, acc: 0.33333
# [epoch 31/100, episode 50/100] => loss: 1.94339, acc: 0.39667
# [epoch 31/100, episode 100/100] => loss: 2.21923, acc: 0.33000
# [epoch 32/100, episode 50/100] => loss: 2.20869, acc: 0.31333
# [epoch 32/100, episode 100/100] => loss: 2.02723, acc: 0.34333
# Testing...
# Average Test Accuracy: 0.25275
# [epoch 33/100, episode 50/100] => loss: 2.06929, acc: 0.35333
# [epoch 33/100, episode 100/100] => loss: 1.78401, acc: 0.47000
# [epoch 34/100, episode 50/100] => loss: 1.78837, acc: 0.44000
# [epoch 34/100, episode 100/100] => loss: 1.88230, acc: 0.43000
# [epoch 35/100, episode 50/100] => loss: 1.77681, acc: 0.43333
# [epoch 35/100, episode 100/100] => loss: 2.06237, acc: 0.35667
# Testing...
# Average Test Accuracy: 0.25120
# [epoch 36/100, episode 50/100] => loss: 2.07960, acc: 0.36000
# [epoch 36/100, episode 100/100] => loss: 1.99231, acc: 0.39000
# [epoch 37/100, episode 50/100] => loss: 2.02407, acc: 0.34000
# [epoch 37/100, episode 100/100] => loss: 1.89013, acc: 0.37333
# [epoch 38/100, episode 50/100] => loss: 1.87636, acc: 0.37000
# [epoch 38/100, episode 100/100] => loss: 1.91083, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.25642
# [epoch 39/100, episode 50/100] => loss: 1.95748, acc: 0.39333
# [epoch 39/100, episode 100/100] => loss: 2.27503, acc: 0.30000
# [epoch 40/100, episode 50/100] => loss: 1.76884, acc: 0.42333
# [epoch 40/100, episode 100/100] => loss: 1.92164, acc: 0.38333
# [epoch 41/100, episode 50/100] => loss: 1.92647, acc: 0.39000
# [epoch 41/100, episode 100/100] => loss: 1.66326, acc: 0.46667
# Testing...
# Average Test Accuracy: 0.26275
# [epoch 42/100, episode 50/100] => loss: 1.95647, acc: 0.41000
# [epoch 42/100, episode 100/100] => loss: 1.74990, acc: 0.44333
# [epoch 43/100, episode 50/100] => loss: 1.83825, acc: 0.40000
# [epoch 43/100, episode 100/100] => loss: 2.06030, acc: 0.34000
# [epoch 44/100, episode 50/100] => loss: 1.78305, acc: 0.44000
# [epoch 44/100, episode 100/100] => loss: 1.84003, acc: 0.40000
# Testing...
# Average Test Accuracy: 0.25908
# [epoch 45/100, episode 50/100] => loss: 1.85214, acc: 0.41000
# [epoch 45/100, episode 100/100] => loss: 1.87889, acc: 0.41000
# [epoch 46/100, episode 50/100] => loss: 1.79679, acc: 0.44000
# [epoch 46/100, episode 100/100] => loss: 1.85472, acc: 0.40667
# [epoch 47/100, episode 50/100] => loss: 1.89064, acc: 0.41000
# [epoch 47/100, episode 100/100] => loss: 1.86207, acc: 0.42667
# Testing...
# Average Test Accuracy: 0.25152
# [epoch 48/100, episode 50/100] => loss: 2.03372, acc: 0.37000
# [epoch 48/100, episode 100/100] => loss: 2.15746, acc: 0.37667
# [epoch 49/100, episode 50/100] => loss: 1.81533, acc: 0.39667
# [epoch 49/100, episode 100/100] => loss: 1.64844, acc: 0.50000
# [epoch 50/100, episode 50/100] => loss: 1.70254, acc: 0.47000
# [epoch 50/100, episode 100/100] => loss: 2.05405, acc: 0.35000
# Testing...
# Average Test Accuracy: 0.26620
# [epoch 51/100, episode 50/100] => loss: 1.71291, acc: 0.45333
# [epoch 51/100, episode 100/100] => loss: 1.85295, acc: 0.42000
# [epoch 52/100, episode 50/100] => loss: 1.91095, acc: 0.40667
# [epoch 52/100, episode 100/100] => loss: 2.09308, acc: 0.32667
# [epoch 53/100, episode 50/100] => loss: 1.59839, acc: 0.47000
# [epoch 53/100, episode 100/100] => loss: 1.76477, acc: 0.44000
# Testing...
# Average Test Accuracy: 0.25171
# [epoch 54/100, episode 50/100] => loss: 1.74912, acc: 0.46667
# [epoch 54/100, episode 100/100] => loss: 1.59758, acc: 0.50333
# [epoch 55/100, episode 50/100] => loss: 1.97445, acc: 0.39000
# [epoch 55/100, episode 100/100] => loss: 1.67104, acc: 0.44000
# [epoch 56/100, episode 50/100] => loss: 1.72160, acc: 0.46667
# [epoch 56/100, episode 100/100] => loss: 1.98551, acc: 0.35333
# Testing...
# Average Test Accuracy: 0.26472
# [epoch 57/100, episode 50/100] => loss: 1.85742, acc: 0.39000
# [epoch 57/100, episode 100/100] => loss: 1.57363, acc: 0.49000
# [epoch 58/100, episode 50/100] => loss: 1.69760, acc: 0.44000
# [epoch 58/100, episode 100/100] => loss: 2.03391, acc: 0.33000
# [epoch 59/100, episode 50/100] => loss: 1.66907, acc: 0.43333
# [epoch 59/100, episode 100/100] => loss: 1.79310, acc: 0.42000
# Testing...
# Average Test Accuracy: 0.26093
# [epoch 60/100, episode 50/100] => loss: 1.62678, acc: 0.46333
# [epoch 60/100, episode 100/100] => loss: 1.64902, acc: 0.45333
# [epoch 61/100, episode 50/100] => loss: 1.90944, acc: 0.39667
# [epoch 61/100, episode 100/100] => loss: 1.74483, acc: 0.46000
# [epoch 62/100, episode 50/100] => loss: 1.66674, acc: 0.50667
# [epoch 62/100, episode 100/100] => loss: 1.70964, acc: 0.44000
# Testing...
# Average Test Accuracy: 0.26732
# [epoch 63/100, episode 50/100] => loss: 1.48905, acc: 0.53667
# [epoch 63/100, episode 100/100] => loss: 1.74443, acc: 0.46000
# [epoch 64/100, episode 50/100] => loss: 1.88797, acc: 0.42333
# [epoch 64/100, episode 100/100] => loss: 1.74803, acc: 0.47667
# [epoch 65/100, episode 50/100] => loss: 1.73559, acc: 0.46000
# [epoch 65/100, episode 100/100] => loss: 1.72068, acc: 0.45000
# Testing...
# Average Test Accuracy: 0.26098
# [epoch 66/100, episode 50/100] => loss: 1.85783, acc: 0.44333
# [epoch 66/100, episode 100/100] => loss: 1.76552, acc: 0.42667
# [epoch 67/100, episode 50/100] => loss: 1.88349, acc: 0.37667
# [epoch 67/100, episode 100/100] => loss: 1.96995, acc: 0.40000
# [epoch 68/100, episode 50/100] => loss: 2.09440, acc: 0.30667
# [epoch 68/100, episode 100/100] => loss: 1.68225, acc: 0.49000
# Testing...
# Average Test Accuracy: 0.26425
# [epoch 69/100, episode 50/100] => loss: 1.96947, acc: 0.42667
# [epoch 69/100, episode 100/100] => loss: 1.90592, acc: 0.39667
# [epoch 70/100, episode 50/100] => loss: 1.61603, acc: 0.48000
# [epoch 70/100, episode 100/100] => loss: 1.70760, acc: 0.44667
# [epoch 71/100, episode 50/100] => loss: 1.73593, acc: 0.44000
# [epoch 71/100, episode 100/100] => loss: 2.08227, acc: 0.37667
# Testing...
# Average Test Accuracy: 0.26557
# [epoch 72/100, episode 50/100] => loss: 1.67210, acc: 0.48333
# [epoch 72/100, episode 100/100] => loss: 1.65499, acc: 0.45667
# [epoch 73/100, episode 50/100] => loss: 1.91397, acc: 0.38333
# [epoch 73/100, episode 100/100] => loss: 1.86004, acc: 0.42000
# [epoch 74/100, episode 50/100] => loss: 1.79606, acc: 0.44000
# [epoch 74/100, episode 100/100] => loss: 1.63899, acc: 0.48667
# Testing...
# Average Test Accuracy: 0.26262
# [epoch 75/100, episode 50/100] => loss: 1.65862, acc: 0.47333
# [epoch 75/100, episode 100/100] => loss: 1.71861, acc: 0.41333
# [epoch 76/100, episode 50/100] => loss: 2.00563, acc: 0.38000
# [epoch 76/100, episode 100/100] => loss: 1.54623, acc: 0.50000
# [epoch 77/100, episode 50/100] => loss: 1.39481, acc: 0.52000
# [epoch 77/100, episode 100/100] => loss: 1.70596, acc: 0.46667
# Testing...
# Average Test Accuracy: 0.25841
# [epoch 78/100, episode 50/100] => loss: 1.64029, acc: 0.46667
# [epoch 78/100, episode 100/100] => loss: 2.02105, acc: 0.37000
# [epoch 79/100, episode 50/100] => loss: 1.40799, acc: 0.56000
# [epoch 79/100, episode 100/100] => loss: 1.40199, acc: 0.52667
# [epoch 80/100, episode 50/100] => loss: 1.64876, acc: 0.51000
# [epoch 80/100, episode 100/100] => loss: 1.58211, acc: 0.52667
# Testing...
# Average Test Accuracy: 0.26423
# [epoch 81/100, episode 50/100] => loss: 1.62635, acc: 0.50667
# [epoch 81/100, episode 100/100] => loss: 1.52848, acc: 0.50667
# [epoch 82/100, episode 50/100] => loss: 1.53272, acc: 0.51667
# [epoch 82/100, episode 100/100] => loss: 1.57603, acc: 0.50667
# [epoch 83/100, episode 50/100] => loss: 1.64005, acc: 0.42333
# [epoch 83/100, episode 100/100] => loss: 1.73234, acc: 0.48333
# Testing...
# Average Test Accuracy: 0.26656
# [epoch 84/100, episode 50/100] => loss: 1.43710, acc: 0.52000
# [epoch 84/100, episode 100/100] => loss: 1.72918, acc: 0.45000
# [epoch 85/100, episode 50/100] => loss: 1.37226, acc: 0.51667
# [epoch 85/100, episode 100/100] => loss: 1.40467, acc: 0.54000
# [epoch 86/100, episode 50/100] => loss: 1.80011, acc: 0.39333
# [epoch 86/100, episode 100/100] => loss: 1.64320, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.26057
# [epoch 87/100, episode 50/100] => loss: 1.42597, acc: 0.54667
# [epoch 87/100, episode 100/100] => loss: 1.76698, acc: 0.43667
# [epoch 88/100, episode 50/100] => loss: 1.55616, acc: 0.53667
# [epoch 88/100, episode 100/100] => loss: 1.41300, acc: 0.54333
# [epoch 89/100, episode 50/100] => loss: 1.39452, acc: 0.54000
# [epoch 89/100, episode 100/100] => loss: 1.38758, acc: 0.52667
# Testing...
# Average Test Accuracy: 0.26086
# [epoch 90/100, episode 50/100] => loss: 1.67933, acc: 0.42667
# [epoch 90/100, episode 100/100] => loss: 1.66999, acc: 0.46000
# [epoch 91/100, episode 50/100] => loss: 1.73167, acc: 0.46667
# [epoch 91/100, episode 100/100] => loss: 1.95365, acc: 0.43333
# [epoch 92/100, episode 50/100] => loss: 1.68383, acc: 0.47000
# [epoch 92/100, episode 100/100] => loss: 1.62386, acc: 0.48000
# Testing...
# Average Test Accuracy: 0.25606
# [epoch 93/100, episode 50/100] => loss: 1.44311, acc: 0.54333
# [epoch 93/100, episode 100/100] => loss: 1.53675, acc: 0.48000
# [epoch 94/100, episode 50/100] => loss: 1.82441, acc: 0.43667
# [epoch 94/100, episode 100/100] => loss: 1.63154, acc: 0.44333
# [epoch 95/100, episode 50/100] => loss: 1.66404, acc: 0.43667
# [epoch 95/100, episode 100/100] => loss: 1.87297, acc: 0.44000
# Testing...
# Average Test Accuracy: 0.26043
# [epoch 96/100, episode 50/100] => loss: 1.66755, acc: 0.41333
# [epoch 96/100, episode 100/100] => loss: 1.42691, acc: 0.55667
# [epoch 97/100, episode 50/100] => loss: 1.26500, acc: 0.60000
# [epoch 97/100, episode 100/100] => loss: 1.72728, acc: 0.44000
# [epoch 98/100, episode 50/100] => loss: 1.77622, acc: 0.43000
# [epoch 98/100, episode 100/100] => loss: 1.60869, acc: 0.46333
# Testing...
# Average Test Accuracy: 0.26355
# [epoch 99/100, episode 50/100] => loss: 1.59469, acc: 0.51333
# [epoch 99/100, episode 100/100] => loss: 1.71444, acc: 0.50667
# [epoch 100/100, episode 50/100] => loss: 1.83456, acc: 0.41000
# [epoch 100/100, episode 100/100] => loss: 1.40305, acc: 0.55667
# Training is over.
# Testing...
# Average Test Accuracy: 0.25974

# %%
'''
import glob
import os
import numpy as np
import cv2

n_train_classes = 64
n_test_classes = 20
n_examples, width, height, channels = 600, 84, 84, 3

root_path = '/content/drive/My Drive/data/miniimagenet'
train_path = os.path.join(root_path, 'train')
test_path = os.path.join(root_path, 'test')

train_dirs = [f for f in glob.glob(os.path.join(train_path, '*')) if os.path.isdir(f)]
test_dirs = [f for f in glob.glob(os.path.join(test_path, '*')) if os.path.isdir(f)]
print(len(train_dirs))

assert len(train_dirs) == n_train_classes
assert len(test_dirs) == n_test_classes

read_and_resize = lambda x: cv2.imread(x, 1)

def sample_dataset(dataset, dirs, name='train'):
    for i, d in enumerate(dirs):
        fs = np.asarray(glob.glob(os.path.join(d, '*.jpg')))
        fs = fs[np.random.permutation(len(fs))][:n_examples]
        for j, f in enumerate(fs):
            dataset[i, j] = read_and_resize(f)
        print('{}: {} of {}'.format(name, i + 1, len(dirs)))
    return dataset

train_dataset = np.zeros((n_train_classes, n_examples, width, height, channels), dtype=np.uint8)
train_dataset = sample_dataset(train_dataset, train_dirs)
np.save('/content/drive/My Drive/data/mini-imagenet-train_600.npy', train_dataset)
del train_dataset

test_dataset = np.zeros((n_test_classes, n_examples, width, height, channels), dtype=np.uint8)
test_dataset = sample_dataset(test_dataset, test_dirs, name='test')
np.save('/content/drive/My Drive/data/mini-imagenet-test_600.npy', test_dataset)
'''

# %%
img = tf.Variable(tf.random_normal([3, 4]))
axis = list(range(len(img.get_shape()) - 1))
mean, variance = tf.nn.moments(img, axis)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    rs = sess.run(img)
    print(rs)
    print(rs.shape)
    print(axis)
    resultMean = sess.run(mean)
    print('resultMean',resultMean)
    resultVar = sess.run(variance)
    print('resultVar',resultVar)
# Out:
# [[-0.15628773 -0.04902783  1.0848862  -1.4387043 ]
#  [-1.7748989  -1.9277954   1.2477913  -0.14888158]
#  [-0.31883678 -0.5837216  -2.0567434   0.48701447]]
# (3, 4)
# [0]
# resultMean [-0.7500078  -0.8535149   0.09197799 -0.36685714]
# resultVar [0.5296046  0.62468886 2.312925   0.6418221 ]

# %%
#!unzip miniimagenet.zip > /dev/null
