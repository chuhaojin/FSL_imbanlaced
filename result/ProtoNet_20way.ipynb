# %%
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14912199066
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 225273831512821933
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# [None]

# %%
import numpy as np
print(np.random.randint(1, 6, size=10))

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.client import device_lib
# 列出所有的本地机器设备
local_device_protos = device_lib.list_local_devices()
# 只打印GPU设备
[print(x) for x in local_device_protos if x.device_type == 'GPU']


n_epochs = 100
n_episodes = 100
n_way = 20
n_shot = 5
n_query = 15
n_examples = 350
im_width, im_height, channels = 84, 84, 3
h_dim = 64
z_dim = 64

# Load Train Dataset
train_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-train_600.npy')
train_dataset = train_dataset[:,:n_examples]
n_classes = train_dataset.shape[0]
print(train_dataset.shape)

test_dataset = np.load('/content/drive/My Drive/data/mini-imagenet-test_600.npy')
n_test_classes = test_dataset.shape[0]
print(test_dataset.shape)
n_test_episodes = 600
n_test_examples = 600
n_test_way = 20
n_test_shot = 5
n_test_query = 15

'''
epi_classes = np.random.permutation(n_classes)[:n_way]
support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
for i, epi_cls in enumerate(epi_classes):
    selected = np.random.permutation(n_examples)[:n_shot + n_query]
    support[i] = train_dataset[epi_cls, selected[:n_shot]]
    query[i] = train_dataset[epi_cls, selected[n_shot:]]
# support = np.expand_dims(support, axis=-1)
# query = np.expand_dims(query, axis=-1)
labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
'''


def conv_block(inputs, out_channels, name='conv'):
    with tf.variable_scope(name):
        conv = tf.layers.conv2d(inputs, out_channels, kernel_size=3, padding='SAME')
        conv = tf.contrib.layers.batch_norm(conv, updates_collections=None, decay=0.99, scale=True, center=True)
        conv = tf.nn.relu(conv)
        conv = tf.contrib.layers.max_pool2d(conv, 2)
        return conv


def encoder(x, h_dim, z_dim, reuse=False):
    with tf.variable_scope('encoder', reuse=reuse):
        net = conv_block(x, h_dim, name='conv_1')
        net = conv_block(net, h_dim, name='conv_2')
        net = conv_block(net, h_dim, name='conv_3')
        net = conv_block(net, z_dim, name='conv_4')
        net = tf.contrib.layers.flatten(net)
        return net


def euclidean_distance(a, b):
    # a.shape = N x D
    # b.shape = M x D
    N, D = tf.shape(a)[0], tf.shape(a)[1]
    M = tf.shape(b)[0]
    a = tf.tile(tf.expand_dims(a, axis=1), (1, M, 1))
    b = tf.tile(tf.expand_dims(b, axis=0), (N, 1, 1))
    return tf.reduce_mean(tf.square(a - b), axis=2)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14912199066
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6254082907959188565
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#
# (64, 350, 84, 84, 3)
# (20, 600, 84, 84, 3)

# %%
def oversampling(batch_data, few_shot):
  balanced_data = np.zeros(batch_data.shape)
  balanced_data = np.copy(batch_data)
  temp_shot = len(batch_data[0])
  for i, n_few in enumerate(few_shot):
    choosed = np.random.randint(0, n_few, size=temp_shot - n_few)
    balanced_data[i, n_few:] = batch_data[i, choosed]
  return balanced_data


def require_unbalanced_data(train_dataset,
               n_classes=n_classes,
               n_way=n_way,
               n_shot=n_shot,
               n_query=n_query,
               n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  n_few_shot = np.random.randint(1, n_shot+1, size=n_way)
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
    selected = np.random.permutation(n_examples)[:n_few_shot[i] + n_query]
    support[i,:n_few_shot[i]] = train_dataset[epi_cls, selected[:n_few_shot[i]]]
    query[i] = train_dataset[epi_cls, selected[n_few_shot[i]:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels, n_few_shot


def uniform_sampling(train_dataset,
           n_classes=n_classes,
           n_way=n_way,
           n_shot=n_shot,
           n_query=n_query,
           n_examples=n_examples):
  epi_classes = np.random.permutation(n_classes)[:n_way]
  support = np.zeros([n_way, n_shot, im_height, im_width, channels], dtype=np.float32)
  query = np.zeros([n_way, n_query, im_height, im_width, channels], dtype=np.float32)
  for i, epi_cls in enumerate(epi_classes):
      selected = np.random.permutation(n_examples)[:n_shot + n_query]
      support[i] = train_dataset[epi_cls, selected[:n_shot]]
      query[i] = train_dataset[epi_cls, selected[n_shot:]]
  labels = np.tile(np.arange(n_way)[:, np.newaxis], (1, n_query)).astype(np.uint8)
  return support, query, labels


def test_bench(sess,
        test_dataset,
        n_test_classes = n_test_classes,
        n_test_episodes=n_test_episodes, 
        n_test_way = n_test_way,
        n_test_shot = n_test_shot,
        n_test_query = n_test_query,
        n_test_examples=n_test_examples):
  print('Testing...')
  avg_acc = 0.
  n_test_classes = test_dataset.shape[0]
  for epi in range(n_test_episodes):
    # support, query, labels = uniform_sampling(test_dataset,
    #        n_classes=n_test_classes,
    #        n_way=n_test_way,
    #        n_shot=n_test_shot,
    #        n_query=n_test_query,
    #        n_examples=n_test_examples)
    support, query, labels, n_few_shot = require_unbalanced_data(test_dataset,
                                    n_classes=n_test_classes,
                                    n_way=n_test_way,
                                    n_shot=n_test_shot,
                                    n_query=n_test_query,
                                    n_examples=n_test_examples)
    support = oversampling(support, n_few_shot)
    ls, ac, = sess.run([ce_loss, acc], feed_dict={x: support, q: query, y:labels})
    avg_acc += ac
  avg_acc /= n_test_episodes
  print('Average Test Accuracy: {:.5f}'.format(avg_acc))
  return None

# %%
x = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
q = tf.placeholder(tf.float32, [None, None, im_height, im_width, channels])
var_weight = tf.get_variable(name="variance_weight", shape=(1, 1))
var_b = tf.get_variable(name="variance_bias", shape=(1))
x_shape = tf.shape(x)
q_shape = tf.shape(q)
num_classes, num_support = x_shape[0], x_shape[1]
num_queries = q_shape[1]
y = tf.placeholder(tf.int64, [None, None])
y_one_hot = tf.one_hot(y, depth=num_classes)
emb_in = encoder(tf.reshape(x, [num_classes * num_support, im_height, im_width, channels]), h_dim, z_dim)
emb_dim = tf.shape(emb_in)[-1]
emb_x, q_variance = tf.nn.moments(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axes=1)
m_variance = tf.reshape(tf.reduce_mean(q_variance, axis=1), [num_classes, 1])
emb_variance = tf.nn.bias_add(tf.matmul(m_variance, var_weight), var_b)
emb_variance = tf.reshape(tf.nn.softmax(emb_variance, axis=0), [1, num_classes])

# emb_variance = tf.nn.softmax(emb_variance, axis=0)
emb_var = tf.tile(emb_variance, [num_queries * num_classes, 1])
# emb_x = tf.reduce_mean(tf.reshape(emb_in, [num_classes, num_support, emb_dim]), axis=1)
emb_q = encoder(tf.reshape(q, [num_classes * num_queries, im_height, im_width, channels]),
                h_dim, z_dim, reuse=True)

# q_mean, q_variance = tf.nn.moments(emb_q, axes=1)
# emb_q = (emb_q - q_mean) / q_variance
dists = euclidean_distance(emb_q, emb_x)
# amend_dists = tf.multiply(emb_var, dists) * tf.to_float(num_classes)
log_p_y = tf.reshape(tf.nn.log_softmax(-dists), [num_classes, num_queries, -1])
ce_loss = -tf.reduce_mean(tf.reshape(tf.reduce_sum(tf.multiply(y_one_hot, log_p_y), axis=-1), [-1]))
acc = tf.reduce_mean(tf.to_float(tf.equal(tf.argmax(log_p_y, axis=-1), y)))

train_op = tf.train.AdamOptimizer().minimize(ce_loss)

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
init_op = tf.global_variables_initializer()
sess.run(init_op)
# Out:
# WARNING:tensorflow:From <ipython-input-1-cb5a1d61a2f4>:51: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-3-f8e625e5d02d>:30: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
n_epochs = 100
for ep in range(n_epochs):
    for epi in range(n_episodes):
        # support, query, labels = uniform_sampling(train_dataset)
        support, query, labels, n_few_shot = require_unbalanced_data(train_dataset)
        support = oversampling(support, n_few_shot)
        _, ls, ac = sess.run([train_op, ce_loss, acc], feed_dict={x: support, q: query, y:labels})
        if (epi+1) % 50 == 0:
            std_str = '[epoch {}/{}, episode {}/{}] => loss: {:.5f}, acc: {:.5f}'
            print(std_str.format(ep+1, n_epochs, epi+1, n_episodes, ls, ac))
        if (ep + 1) % 3 == 0 and epi == 0:
            # w, b, m_v, emb_v = sess.run([var_weight, var_b, m_variance, emb_variance], 
            #             feed_dict={x: support, q: query, y:labels})
            # print("w:", w, "b:", b)
            # print("mean_var:", m_v)
            # print("emb_v:", emb_v)
            test_bench(sess=sess,test_dataset=test_dataset)
print("Training is over.")
test_bench(sess=sess, test_dataset=test_dataset)
# Out:
# [epoch 1/100, episode 50/100] => loss: 2.71684, acc: 0.18333
# [epoch 1/100, episode 100/100] => loss: 2.68643, acc: 0.20667
# [epoch 2/100, episode 50/100] => loss: 2.67510, acc: 0.23000
# [epoch 2/100, episode 100/100] => loss: 2.76449, acc: 0.20000
# Testing...
# Average Test Accuracy: 0.14960
# [epoch 3/100, episode 50/100] => loss: 2.86650, acc: 0.14333
# [epoch 3/100, episode 100/100] => loss: 2.69692, acc: 0.26333
# [epoch 4/100, episode 50/100] => loss: 2.46911, acc: 0.27000
# [epoch 4/100, episode 100/100] => loss: 2.52122, acc: 0.27667
# [epoch 5/100, episode 50/100] => loss: 2.65585, acc: 0.22000
# [epoch 5/100, episode 100/100] => loss: 2.64591, acc: 0.23333
# Testing...
# Average Test Accuracy: 0.17819
# [epoch 6/100, episode 50/100] => loss: 2.54148, acc: 0.25000
# [epoch 6/100, episode 100/100] => loss: 2.56323, acc: 0.28333
# [epoch 7/100, episode 50/100] => loss: 2.58732, acc: 0.22667
# [epoch 7/100, episode 100/100] => loss: 2.49527, acc: 0.27000
# [epoch 8/100, episode 50/100] => loss: 2.61346, acc: 0.23000
# [epoch 8/100, episode 100/100] => loss: 2.54939, acc: 0.31333
# Testing...
# Average Test Accuracy: 0.19766
# [epoch 9/100, episode 50/100] => loss: 2.47298, acc: 0.20667
# [epoch 9/100, episode 100/100] => loss: 2.50597, acc: 0.23667
# [epoch 10/100, episode 50/100] => loss: 2.44760, acc: 0.32333
# [epoch 10/100, episode 100/100] => loss: 2.29832, acc: 0.34667
# [epoch 11/100, episode 50/100] => loss: 2.49396, acc: 0.29333
# [epoch 11/100, episode 100/100] => loss: 2.56291, acc: 0.24667
# Testing...
# Average Test Accuracy: 0.20391
# [epoch 12/100, episode 50/100] => loss: 2.14913, acc: 0.35000
# [epoch 12/100, episode 100/100] => loss: 2.27680, acc: 0.31000
# [epoch 13/100, episode 50/100] => loss: 2.32811, acc: 0.30333
# [epoch 13/100, episode 100/100] => loss: 2.40659, acc: 0.31667
# [epoch 14/100, episode 50/100] => loss: 2.29153, acc: 0.35667
# [epoch 14/100, episode 100/100] => loss: 2.39942, acc: 0.32667
# Testing...
# Average Test Accuracy: 0.22078
# [epoch 15/100, episode 50/100] => loss: 2.42925, acc: 0.26333
# [epoch 15/100, episode 100/100] => loss: 2.56417, acc: 0.30000
# [epoch 16/100, episode 50/100] => loss: 2.24634, acc: 0.33333
# [epoch 16/100, episode 100/100] => loss: 2.20190, acc: 0.32667
# [epoch 17/100, episode 50/100] => loss: 2.11042, acc: 0.34667
# [epoch 17/100, episode 100/100] => loss: 2.51891, acc: 0.29333
# Testing...
# Average Test Accuracy: 0.22526
# [epoch 18/100, episode 50/100] => loss: 2.33602, acc: 0.32333
# [epoch 18/100, episode 100/100] => loss: 2.33897, acc: 0.31667
# [epoch 19/100, episode 50/100] => loss: 2.47640, acc: 0.29000
# [epoch 19/100, episode 100/100] => loss: 2.29747, acc: 0.32333
# [epoch 20/100, episode 50/100] => loss: 2.33714, acc: 0.29333
# [epoch 20/100, episode 100/100] => loss: 2.03969, acc: 0.46000
# Testing...
# Average Test Accuracy: 0.22994
# [epoch 21/100, episode 50/100] => loss: 2.45506, acc: 0.30667
# [epoch 21/100, episode 100/100] => loss: 2.18821, acc: 0.36000
# [epoch 22/100, episode 50/100] => loss: 2.05719, acc: 0.44000
# [epoch 22/100, episode 100/100] => loss: 2.28879, acc: 0.31333
# [epoch 23/100, episode 50/100] => loss: 2.35197, acc: 0.30667
# [epoch 23/100, episode 100/100] => loss: 2.20250, acc: 0.32000
# Testing...
# Average Test Accuracy: 0.22632
# [epoch 24/100, episode 50/100] => loss: 2.13239, acc: 0.41333
# [epoch 24/100, episode 100/100] => loss: 2.05109, acc: 0.42333
# [epoch 25/100, episode 50/100] => loss: 2.37499, acc: 0.31333
# [epoch 25/100, episode 100/100] => loss: 1.93669, acc: 0.42000
# [epoch 26/100, episode 50/100] => loss: 2.39638, acc: 0.31000
# [epoch 26/100, episode 100/100] => loss: 2.26591, acc: 0.38667
# Testing...
# Average Test Accuracy: 0.22361
# [epoch 27/100, episode 50/100] => loss: 2.31696, acc: 0.32000
# [epoch 27/100, episode 100/100] => loss: 1.98572, acc: 0.41333
# [epoch 28/100, episode 50/100] => loss: 2.17577, acc: 0.31000
# [epoch 28/100, episode 100/100] => loss: 2.54858, acc: 0.24333
# [epoch 29/100, episode 50/100] => loss: 2.11795, acc: 0.36000
# [epoch 29/100, episode 100/100] => loss: 1.97956, acc: 0.42000
# Testing...
# Average Test Accuracy: 0.22541
# [epoch 30/100, episode 50/100] => loss: 2.25770, acc: 0.32000
# [epoch 30/100, episode 100/100] => loss: 2.22769, acc: 0.33333
# [epoch 31/100, episode 50/100] => loss: 2.08885, acc: 0.39333
# [epoch 31/100, episode 100/100] => loss: 1.98127, acc: 0.40333
# [epoch 32/100, episode 50/100] => loss: 1.91839, acc: 0.39667
# [epoch 32/100, episode 100/100] => loss: 2.48125, acc: 0.25000
# Testing...
# Average Test Accuracy: 0.23567
# [epoch 33/100, episode 50/100] => loss: 2.22642, acc: 0.33333
# [epoch 33/100, episode 100/100] => loss: 2.15086, acc: 0.38000
# [epoch 34/100, episode 50/100] => loss: 2.19798, acc: 0.34667
# [epoch 34/100, episode 100/100] => loss: 2.03340, acc: 0.33667
# [epoch 35/100, episode 50/100] => loss: 2.29335, acc: 0.31000
# [epoch 35/100, episode 100/100] => loss: 2.21684, acc: 0.42000
# Testing...
# Average Test Accuracy: 0.22148
# [epoch 36/100, episode 50/100] => loss: 2.29261, acc: 0.31333
# [epoch 36/100, episode 100/100] => loss: 2.33440, acc: 0.31333
# [epoch 37/100, episode 50/100] => loss: 2.16102, acc: 0.41667
# [epoch 37/100, episode 100/100] => loss: 2.09057, acc: 0.37000
# [epoch 38/100, episode 50/100] => loss: 2.39507, acc: 0.27333
# [epoch 38/100, episode 100/100] => loss: 1.73318, acc: 0.46000
# Testing...
# Average Test Accuracy: 0.24431
# [epoch 39/100, episode 50/100] => loss: 2.21771, acc: 0.35000
# [epoch 39/100, episode 100/100] => loss: 2.11081, acc: 0.34667
# [epoch 40/100, episode 50/100] => loss: 2.07563, acc: 0.38000
# [epoch 40/100, episode 100/100] => loss: 2.04983, acc: 0.36667
# [epoch 41/100, episode 50/100] => loss: 2.21102, acc: 0.31333
# [epoch 41/100, episode 100/100] => loss: 2.16126, acc: 0.36333
# Testing...
# Average Test Accuracy: 0.23604
# [epoch 42/100, episode 50/100] => loss: 2.02168, acc: 0.42667
# [epoch 42/100, episode 100/100] => loss: 2.05950, acc: 0.35333
# [epoch 43/100, episode 50/100] => loss: 2.10050, acc: 0.35667
# [epoch 43/100, episode 100/100] => loss: 2.14978, acc: 0.28333
# [epoch 44/100, episode 50/100] => loss: 2.21808, acc: 0.28667
# [epoch 44/100, episode 100/100] => loss: 1.86065, acc: 0.44333
# Testing...
# Average Test Accuracy: 0.24264
# [epoch 45/100, episode 50/100] => loss: 2.07488, acc: 0.38333
# [epoch 45/100, episode 100/100] => loss: 2.14754, acc: 0.31667
# [epoch 46/100, episode 50/100] => loss: 2.28712, acc: 0.32667
# [epoch 46/100, episode 100/100] => loss: 1.96891, acc: 0.37667
# [epoch 47/100, episode 50/100] => loss: 2.08616, acc: 0.45333
# [epoch 47/100, episode 100/100] => loss: 2.23661, acc: 0.29000
# Testing...
# Average Test Accuracy: 0.24226
# [epoch 48/100, episode 50/100] => loss: 2.03504, acc: 0.41000
# [epoch 48/100, episode 100/100] => loss: 2.11584, acc: 0.32333
# [epoch 49/100, episode 50/100] => loss: 2.02432, acc: 0.43000
# [epoch 49/100, episode 100/100] => loss: 2.04613, acc: 0.42000
# [epoch 50/100, episode 50/100] => loss: 1.87898, acc: 0.44000
# [epoch 50/100, episode 100/100] => loss: 1.85220, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.23523
# [epoch 51/100, episode 50/100] => loss: 1.91716, acc: 0.45000
# [epoch 51/100, episode 100/100] => loss: 2.01793, acc: 0.39000
# [epoch 52/100, episode 50/100] => loss: 1.89300, acc: 0.41333
# [epoch 52/100, episode 100/100] => loss: 2.00364, acc: 0.36333
# [epoch 53/100, episode 50/100] => loss: 2.13649, acc: 0.36000
# [epoch 53/100, episode 100/100] => loss: 2.10013, acc: 0.38333
# Testing...
# Average Test Accuracy: 0.23990
# [epoch 54/100, episode 50/100] => loss: 2.07137, acc: 0.39000
# [epoch 54/100, episode 100/100] => loss: 2.03292, acc: 0.37667
# [epoch 55/100, episode 50/100] => loss: 2.29331, acc: 0.31000
# [epoch 55/100, episode 100/100] => loss: 1.88312, acc: 0.42667
# [epoch 56/100, episode 50/100] => loss: 1.92131, acc: 0.39667
# [epoch 56/100, episode 100/100] => loss: 1.92840, acc: 0.43667
# Testing...
# Average Test Accuracy: 0.24573
# [epoch 57/100, episode 50/100] => loss: 1.88321, acc: 0.45333
# [epoch 57/100, episode 100/100] => loss: 2.11748, acc: 0.44000
# [epoch 58/100, episode 50/100] => loss: 2.08424, acc: 0.36333
# [epoch 58/100, episode 100/100] => loss: 2.07516, acc: 0.35667
# [epoch 59/100, episode 50/100] => loss: 2.11784, acc: 0.36667
# [epoch 59/100, episode 100/100] => loss: 1.86678, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.24677
# [epoch 60/100, episode 50/100] => loss: 1.83419, acc: 0.45667
# [epoch 60/100, episode 100/100] => loss: 2.13509, acc: 0.34000
# [epoch 61/100, episode 50/100] => loss: 2.12380, acc: 0.38000
# [epoch 61/100, episode 100/100] => loss: 1.98289, acc: 0.40000
# [epoch 62/100, episode 50/100] => loss: 2.21601, acc: 0.35667
# [epoch 62/100, episode 100/100] => loss: 2.06232, acc: 0.40333
# Testing...
# Average Test Accuracy: 0.24823
# [epoch 63/100, episode 50/100] => loss: 2.02314, acc: 0.38333
# [epoch 63/100, episode 100/100] => loss: 1.90337, acc: 0.39667
# [epoch 64/100, episode 50/100] => loss: 1.98602, acc: 0.37333
# [epoch 64/100, episode 100/100] => loss: 1.78741, acc: 0.47333
# [epoch 65/100, episode 50/100] => loss: 2.05756, acc: 0.37667
# [epoch 65/100, episode 100/100] => loss: 1.90266, acc: 0.40000
# Testing...
# Average Test Accuracy: 0.24693
# [epoch 66/100, episode 50/100] => loss: 1.93977, acc: 0.38333
# [epoch 66/100, episode 100/100] => loss: 1.93088, acc: 0.43000
# [epoch 67/100, episode 50/100] => loss: 1.95086, acc: 0.38333
# [epoch 67/100, episode 100/100] => loss: 2.03570, acc: 0.39667
# [epoch 68/100, episode 50/100] => loss: 1.78098, acc: 0.48333
# [epoch 68/100, episode 100/100] => loss: 2.05085, acc: 0.40667
# Testing...
# Average Test Accuracy: 0.24858
# [epoch 69/100, episode 50/100] => loss: 2.14660, acc: 0.40000
# [epoch 69/100, episode 100/100] => loss: 1.74699, acc: 0.44333
# [epoch 70/100, episode 50/100] => loss: 1.98014, acc: 0.39667
# [epoch 70/100, episode 100/100] => loss: 1.82646, acc: 0.41000
# [epoch 71/100, episode 50/100] => loss: 1.70483, acc: 0.48000
# [epoch 71/100, episode 100/100] => loss: 1.95872, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.24240
# [epoch 72/100, episode 50/100] => loss: 1.98509, acc: 0.34667
# [epoch 72/100, episode 100/100] => loss: 1.92376, acc: 0.41000
# [epoch 73/100, episode 50/100] => loss: 2.13913, acc: 0.37000
# [epoch 73/100, episode 100/100] => loss: 2.39310, acc: 0.31000
# [epoch 74/100, episode 50/100] => loss: 2.17041, acc: 0.38000
# [epoch 74/100, episode 100/100] => loss: 1.54829, acc: 0.51667
# Testing...
# Average Test Accuracy: 0.23944
# [epoch 75/100, episode 50/100] => loss: 2.09554, acc: 0.40333
# [epoch 75/100, episode 100/100] => loss: 2.06804, acc: 0.35667
# [epoch 76/100, episode 50/100] => loss: 1.87491, acc: 0.46000
# [epoch 76/100, episode 100/100] => loss: 1.74800, acc: 0.44000
# [epoch 77/100, episode 50/100] => loss: 2.16668, acc: 0.40000
# [epoch 77/100, episode 100/100] => loss: 1.87383, acc: 0.46000
# Testing...
# Average Test Accuracy: 0.24362
# [epoch 78/100, episode 50/100] => loss: 2.15556, acc: 0.37000
# [epoch 78/100, episode 100/100] => loss: 2.15289, acc: 0.36333
# [epoch 79/100, episode 50/100] => loss: 1.70438, acc: 0.50000
# [epoch 79/100, episode 100/100] => loss: 2.01796, acc: 0.46333
# [epoch 80/100, episode 50/100] => loss: 1.78793, acc: 0.48333
# [epoch 80/100, episode 100/100] => loss: 1.80614, acc: 0.45000
# Testing...
# Average Test Accuracy: 0.24723
# [epoch 81/100, episode 50/100] => loss: 2.13146, acc: 0.32667
# [epoch 81/100, episode 100/100] => loss: 1.83289, acc: 0.42667
# [epoch 82/100, episode 50/100] => loss: 2.05355, acc: 0.39000
# [epoch 82/100, episode 100/100] => loss: 1.86157, acc: 0.49000
# [epoch 83/100, episode 50/100] => loss: 2.08772, acc: 0.36333
# [epoch 83/100, episode 100/100] => loss: 1.92339, acc: 0.41333
# Testing...
# Average Test Accuracy: 0.24171
# [epoch 84/100, episode 50/100] => loss: 1.74784, acc: 0.46333
# [epoch 84/100, episode 100/100] => loss: 2.08224, acc: 0.39333
# [epoch 85/100, episode 50/100] => loss: 1.95391, acc: 0.35333
# [epoch 85/100, episode 100/100] => loss: 1.83287, acc: 0.45000
# [epoch 86/100, episode 50/100] => loss: 1.72020, acc: 0.46333
# [epoch 86/100, episode 100/100] => loss: 2.09381, acc: 0.36333
# Testing...
# Average Test Accuracy: 0.24085
# [epoch 87/100, episode 50/100] => loss: 2.14417, acc: 0.34000
# [epoch 87/100, episode 100/100] => loss: 1.75514, acc: 0.47000
# [epoch 88/100, episode 50/100] => loss: 1.86238, acc: 0.43333
# [epoch 88/100, episode 100/100] => loss: 1.97852, acc: 0.42667
# [epoch 89/100, episode 50/100] => loss: 1.87037, acc: 0.43000
# [epoch 89/100, episode 100/100] => loss: 2.06883, acc: 0.42667
# Testing...
# Average Test Accuracy: 0.24361
# [epoch 90/100, episode 50/100] => loss: 1.80488, acc: 0.45667
# [epoch 90/100, episode 100/100] => loss: 1.58492, acc: 0.48333
# [epoch 91/100, episode 50/100] => loss: 1.92183, acc: 0.40333
# [epoch 91/100, episode 100/100] => loss: 1.91049, acc: 0.54333
# [epoch 92/100, episode 50/100] => loss: 2.04406, acc: 0.41000
# [epoch 92/100, episode 100/100] => loss: 2.05990, acc: 0.37000
# Testing...
# Average Test Accuracy: 0.24148
# [epoch 93/100, episode 50/100] => loss: 1.89325, acc: 0.45667
# [epoch 93/100, episode 100/100] => loss: 1.87402, acc: 0.43333
# [epoch 94/100, episode 50/100] => loss: 1.91026, acc: 0.42000
# [epoch 94/100, episode 100/100] => loss: 2.06053, acc: 0.36667
# [epoch 95/100, episode 50/100] => loss: 1.84740, acc: 0.40667
# [epoch 95/100, episode 100/100] => loss: 1.83449, acc: 0.45333
# Testing...
# Average Test Accuracy: 0.24196
# [epoch 96/100, episode 50/100] => loss: 1.94634, acc: 0.38667
# [epoch 96/100, episode 100/100] => loss: 2.05484, acc: 0.34333
# [epoch 97/100, episode 50/100] => loss: 2.27048, acc: 0.30667
# [epoch 97/100, episode 100/100] => loss: 1.89459, acc: 0.43000
# [epoch 98/100, episode 50/100] => loss: 2.30041, acc: 0.36667
# [epoch 98/100, episode 100/100] => loss: 2.19903, acc: 0.33667
# Testing...
# Average Test Accuracy: 0.24224
# [epoch 99/100, episode 50/100] => loss: 1.86808, acc: 0.40333
# [epoch 99/100, episode 100/100] => loss: 2.09480, acc: 0.37667
# [epoch 100/100, episode 50/100] => loss: 1.78415, acc: 0.42000
# [epoch 100/100, episode 100/100] => loss: 1.54916, acc: 0.49667
# Training is over.
# Testing...
# Average Test Accuracy: 0.24401

# %%
'''
import glob
import os
import numpy as np
import cv2

n_train_classes = 64
n_test_classes = 20
n_examples, width, height, channels = 600, 84, 84, 3

root_path = '/content/drive/My Drive/data/miniimagenet'
train_path = os.path.join(root_path, 'train')
test_path = os.path.join(root_path, 'test')

train_dirs = [f for f in glob.glob(os.path.join(train_path, '*')) if os.path.isdir(f)]
test_dirs = [f for f in glob.glob(os.path.join(test_path, '*')) if os.path.isdir(f)]
print(len(train_dirs))

assert len(train_dirs) == n_train_classes
assert len(test_dirs) == n_test_classes

read_and_resize = lambda x: cv2.imread(x, 1)

def sample_dataset(dataset, dirs, name='train'):
    for i, d in enumerate(dirs):
        fs = np.asarray(glob.glob(os.path.join(d, '*.jpg')))
        fs = fs[np.random.permutation(len(fs))][:n_examples]
        for j, f in enumerate(fs):
            dataset[i, j] = read_and_resize(f)
        print('{}: {} of {}'.format(name, i + 1, len(dirs)))
    return dataset

train_dataset = np.zeros((n_train_classes, n_examples, width, height, channels), dtype=np.uint8)
train_dataset = sample_dataset(train_dataset, train_dirs)
np.save('/content/drive/My Drive/data/mini-imagenet-train_600.npy', train_dataset)
del train_dataset

test_dataset = np.zeros((n_test_classes, n_examples, width, height, channels), dtype=np.uint8)
test_dataset = sample_dataset(test_dataset, test_dirs, name='test')
np.save('/content/drive/My Drive/data/mini-imagenet-test_600.npy', test_dataset)
'''

# %%
img = tf.Variable(tf.random_normal([3, 4]))
axis = list(range(len(img.get_shape()) - 1))
mean, variance = tf.nn.moments(img, axis)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    rs = sess.run(img)
    print(rs)
    print(rs.shape)
    print(axis)
    resultMean = sess.run(mean)
    print('resultMean',resultMean)
    resultVar = sess.run(variance)
    print('resultVar',resultVar)
# Out:
# [[-0.15628773 -0.04902783  1.0848862  -1.4387043 ]
#  [-1.7748989  -1.9277954   1.2477913  -0.14888158]
#  [-0.31883678 -0.5837216  -2.0567434   0.48701447]]
# (3, 4)
# [0]
# resultMean [-0.7500078  -0.8535149   0.09197799 -0.36685714]
# resultVar [0.5296046  0.62468886 2.312925   0.6418221 ]

# %%
#!unzip miniimagenet.zip > /dev/null
